# %%
import utils
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-50569ac643aa> in <module>()
# ----> 1 import utils
#       2 import cv2
#
# ~/Developer/ALVNS/semantic_segmentation/utils.py in <module>()
#       8 import re
#       9 import cv2
# ---> 10 import semantic_segmentation.configs as configs
#      11 import numpy as np
#      12 import os
#
# ModuleNotFoundError: No module named 'semantic_segmentation'
