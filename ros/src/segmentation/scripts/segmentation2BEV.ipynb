# %%
import cv2
import os, sys
import matplotlib.pyplot as plt
from BirdsEyeView import BirdsEyeView

# %%
image = cv2.imread("/home/neil/images/image-3.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (1242, 375))
plt.imshow(image)
plt.show()

# %%
# BEV class

calib_file = "/home/neil/Desktop/calib/um_000015.txt"

bev = BirdsEyeView()

bev.setup(calib_file)
        
# Compute Birds Eye View
data_bev = bev.compute(image)
        
plt.imshow(data_bev)
